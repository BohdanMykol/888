# %%
import pandas as pd

# %%
sd = pd.read_csv(r'C:\Users\ADMIN\Downloads\pd/survey_results_public.csv')

# %%
sd.shape
# Out:
# (89184, 84)

# %%
sd
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
list(sd.columns)
# Out:
# ['ResponseId',
#  'Q120',
#  'MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'LearnCodeCoursesCert',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'TechList',
#  'BuyNewTool',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
#  'OpSysPersonal use',
#  'OpSysProfessional use',
#  'OfficeStackAsyncHaveWorkedWith',
#  'OfficeStackAsyncWantToWorkWith',
#  'OfficeStackSyncHaveWorkedWith',
#  'OfficeStackSyncWantToWorkWith',
# ...

# %%
schema = pd.read_csv(r'C:\Users\ADMIN\Downloads\pd/survey_results_schema.csv')

# %%
schema
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
ResponsId = sd.dropna(subset='ResponseId').shape[0]
print(f'1. Скільки респондентів пройшли опитування?: {ResponsId}')
# Out:
# 1. Скільки респондентів пройшли опитування?: 89184

# %%
questions = set(schema.qname.unique()) & set(sd.columns)
comp_resp = sd.dropna(subset=questions).shape[0]
print(f'2. Кількість респондентів, які відповіли на всі запитання: {comp_resp}')
# Out:
# 2. Кількість респондентів, які відповіли на всі запитання: 2032

# %%
mean1 = sd['WorkExp'].mean()
median1 = sd['WorkExp'].median()
mode1 = sd['WorkExp'].mode()
print(f'3. Які значення мір центральної тенденції для досвіду (WorkExp) респондентів?: Mean = {mean1}; Median = {median1}; Mode = {mode1}')
# Out:
# 3. Які значення мір центральної тенденції для досвіду (WorkExp) респондентів?: Mean = 11.405126322311204; Median = 9.0; Mode = 0    5.0
# Name: WorkExp, dtype: float64

# %%
umova = sd['RemoteWork'] == 'Remote'
resp_remote = sd[umova]['ResponseId'].count()
print(f'4. Скільки респондентів працює віддалено?: {resp_remote}')
# Out:
# 4. Скільки респондентів працює віддалено?: 30566

# %%
resp_python = sd[sd['LanguageHaveWorkedWith'] == 'Python']['ResponseId'].count()
percent_pyt = round((resp_python/ResponseId)*100, 2)
print(f'5. Який відсоток респондентів програмує на Python?: {percent_pyt}')
# Out:
# 5. Який відсоток респондентів програмує на Python?: 1.27

# %%
on_cour = sd[sd['LearnCode'] == 'Online Courses or Certification']['ResponseId'].count()
print(f'6. Скільки респондентів навчалося програмувати за допомогою онлайн курсів?: {on_cour}')
# Out:
# 6. Скільки респондентів навчалося програмувати за допомогою онлайн курсів?: 594

# %%
gr_ctr = sd[sd['LanguageHaveWorkedWith'] == 'Python'].groupby('Country').agg({'ConvertedCompYearly': ['median', 'mean']}).dropna() 
print(f'7. Серед респондентів що програмують на Python в групуванні по країнам, яка середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні?: {gr_ctr}')
# Out:
# 7. Серед респондентів що програмують на Python в групуванні по країнам, яка середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні?:                                                    ConvertedCompYearly  \
#                                                                 median
# Country
# Argentina                                                      14433.0
# Armenia                                                        60000.0
# Australia                                                      95850.5
# Austria                                                        56222.0
# Azerbaijan                                                     17644.0
# ...                                                                ...
# United Arab Emirates                                           16331.0
# United Kingdom of Great Britain and Northern Ir...             86897.0
# United States of America                                      137500.0
# ...

# %%
converted = sd.sort_values('ConvertedCompYearly', ascending = False)
elevel = converted.iloc[0:5, [7, 83]]
print(f'8. Які рівні освіти мають 5 респондентів з найбільшою компенсацією?:                                                                                     {elevel}')
# Out:
# 8. Які рівні освіти мають 5 респондентів з найбільшою компенсацією?:                                                                                                                                   EdLevel  ConvertedCompYearly
# 53268  Professional degree (JD, MD, Ph.D, Ed.D, etc.)           74351432.0
# 77848  Professional degree (JD, MD, Ph.D, Ed.D, etc.)           73607918.0
# 66223    Bachelor’s degree (B.A., B.S., B.Eng., etc.)           72714292.0
# 28121                       Primary/elementary school           57513831.0
# 19679  Professional degree (JD, MD, Ph.D, Ed.D, etc.)           36573181.0
